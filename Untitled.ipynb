# %%
import pandas as pd

# %%
d =  open('WhatsApp Chat with Civil War💪💪.txt','r',encoding = 'utf-8')
data = d.read()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DHEERA~1\AppData\Local\Temp/ipykernel_15448/3993293784.py in <module>
# ----> 1 data.shape
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
with open(data,'r') as f:
    d = f.readline()
    print(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\DHEERA~1\AppData\Local\Temp/ipykernel_15448/1980214113.py in <module>
# ----> 1 with open(data,'r') as f:
#       2     d = f.readline()
#       3     print(d)
#
# ...

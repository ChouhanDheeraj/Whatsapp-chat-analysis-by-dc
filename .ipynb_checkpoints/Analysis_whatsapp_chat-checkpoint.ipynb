# %%
import re
import pandas as pd

def date_time(s):
        pattern = '^([0-9]+)(\/)([0-9]+)(\/)([0-9]+), ([0-9]+):([0-9]+)[ ]?(AM|PM|am|pm)? -'
        result = re.match(pattern, s)
        if result:
            return True
        else:
            pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
            result = re.match(pattern, s)
            if result:
                return True
            else:
                return False

def getDatapoint(line):
    splitline = line.split(' - ')
    dateTime = splitline[0]
    date, time = dateTime.split(", ")
    message = " ".join(splitline[1:])
    splitmessage = message.split(": ")
    if splitmessage[1:]:
        author = splitmessage[0]
        message = " ".join(splitmessage[1:])
    else:
        author = 'group_notification'
        message = splitmessage[0]
    return date, time, author, message

data = []
conversation = 'WhatsApp Chat with Civil War💪💪.txt'
with open(conversation, encoding="utf-8") as fp:
    fp.readline()
    messageBuffer = []
    date, time, user = None, None, None
    while True:
        line = fp.readline()
        if not line:
               break
        line = line.strip()
        if date_time(line):
            if len(messageBuffer) > 0:
                data.append([date, time, user, ' '.join(messageBuffer)])
            messageBuffer.clear()
            date, time, user, message = getDatapoint(line)
            messageBuffer.append(message)
        else:
            messageBuffer.append(line)

df = pd.DataFrame(data, columns=["date", 'time', 'user', 'message'])

# %%
#f = open('WhatsApp Chat with Civil War💪💪.txt','r',encoding='utf-8')

import datetime as dt
df.head()
# Out:
#          date     time                user  \
# 0  14/12/2021  1:47 am  group_notification
# 1  14/12/2021  1:47 am  group_notification
# 2  14/12/2021  1:47 am  group_notification
# 3  14/12/2021  2:11 am        Karan Dua M3
# 4  14/12/2021  2:11 am        Karan Dua M3
#
#                                    message
# 0  Hritvik M3 created group "Jawahar bois"
# 1                     Hritvik M3 added you
# 2                      You're now an admin
# 3                          <Media omitted>
# 4                          <Media omitted>

# %%
df['date'] = pd.to_datetime(df.date, format='%d/%m/%Y')
#df['date'] = df['date'].dt.strftime('%m-%d-%Y')

# %%
df.head()
df['Year'] = df.date.dt.year

# %%
df['Month_num'] = df['date'].dt.month

# %%
df['Month'] = df['date'].dt.month_name()

# %%
df['Day'] = df.date.dt.day

# %%
df['only_date'] = df['date'].dt.date

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
#df.Time = df['time'].apply(lambda x: df.time(x, '%H:%M: %p').strftime('%I:%M:%S'))
df['Time'] = pd.to_datetime(df.time, format='%I:%M %p')
#df['Time'] = pd.to_datetime(time).strftime('%H:%M:%S'
df['Hours'] = df.Time.dt.hour

# %%
df['Minute']  =df.Time.dt.minute

# %%
df.head(2)
# Out:
#         date     time                user  \
# 0 2021-12-14  1:47 am  group_notification
# 1 2021-12-14  1:47 am  group_notification
#
#                                    message  Year  Month_num     Month  Day  \
# 0  Hritvik M3 created group "Jawahar bois"  2021         12  December   14
# 1                     Hritvik M3 added you  2021         12  December   14
#
#     only_date day_name                Time  Hours  Minute
# 0  2021-12-14  Tuesday 1900-01-01 01:47:00      1      47
# 1  2021-12-14  Tuesday 1900-01-01 01:47:00      1      47

# %%
feature = df[['user','message','Year','Month','Day','Hours','Minute','Month_num','only_date','day_name']]

# %%
feature.head(5)
# Out:
#                  user                                  message  Year  \
# 0  group_notification  Hritvik M3 created group "Jawahar bois"  2021
# 1  group_notification                     Hritvik M3 added you  2021
# 2  group_notification                      You're now an admin  2021
# 3        Karan Dua M3                          <Media omitted>  2021
# 4        Karan Dua M3                          <Media omitted>  2021
#
#       Month  Day  Hours  Minute  Month_num   only_date day_name
# 0  December   14      1      47         12  2021-12-14  Tuesday
# 1  December   14      1      47         12  2021-12-14  Tuesday
# 2  December   14      1      47         12  2021-12-14  Tuesday
# 3  December   14      2      11         12  2021-12-14  Tuesday
# 4  December   14      2      11         12  2021-12-14  Tuesday

# %%
words = []
for message in feature['message']:
    words.extend(message.split())

# %%
num_media_msg = feature[feature['message'] == '<Media omitted>'].shape[0]

# %%
pip install urlextract
# Out:
# Requirement already satisfied: urlextract in c:\users\dheeraj chouhan\appdata\local\programs\python\python39\lib\site-packages (1.6.0)
# Requirement already satisfied: filelock in c:\users\dheeraj chouhan\appdata\local\programs\python\python39\lib\site-packages (from urlextract) (3.0.12)
# Requirement already satisfied: platformdirs in c:\users\dheeraj chouhan\appdata\local\programs\python\python39\lib\site-packages (from urlextract) (2.5.2)
# Requirement already satisfied: idna in c:\users\dheeraj chouhan\appdata\local\programs\python\python39\lib\site-packages (from urlextract) (2.10)
# Requirement already satisfied: uritools in c:\users\dheeraj chouhan\appdata\local\programs\python\python39\lib\site-packages (from urlextract) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\dheeraj chouhan\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from urlextract import URLExtract

# %%
extractor = URLExtract()

# %%
links = []
for message in feature['message']:
    links.extend(extractor.find_urls(message))

# %%
x = feature.user.value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
names = x.index
count = x.values

# %%
plt.figure(figsize = (10,8))
plt.bar(names,count)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
round((feature.user.value_counts()/feature.shape[0])*100,2).reset_index().rename(columns ={'index':'Name','user':'Percent'})
# Out:
#                   Name  Percent
# 0              Dheeraj    22.59
# 1         Karan Dua M3    12.47
# 2        Mohit M4 (CE)    12.28
# 3           Hritvik M3    11.27
# 4             Kesav M4    10.30
# 5          Avnesh Iitr     8.33
# 6             Karan M3     6.76
# 7             Myank M4     5.06
# 8            Jasmin M3     4.09
# 9     Hardik Aseri Jio     4.09
# 10        Deepanshu M2     1.20
# 11  group_notification     0.97
# 12          Diskant M3     0.60

# %%
feature.head()
# Out:
#                  user                                  message  Year  \
# 0  group_notification  Hritvik M3 created group "Jawahar bois"  2021
# 1  group_notification                     Hritvik M3 added you  2021
# 2  group_notification                      You're now an admin  2021
# 3        Karan Dua M3                          <Media omitted>  2021
# 4        Karan Dua M3                          <Media omitted>  2021
#
#       Month  Day  Hours  Minute  Month_num   only_date day_name
# 0  December   14      1      47         12  2021-12-14  Tuesday
# 1  December   14      1      47         12  2021-12-14  Tuesday
# 2  December   14      1      47         12  2021-12-14  Tuesday
# 3  December   14      2      11         12  2021-12-14  Tuesday
# 4  December   14      2      11         12  2021-12-14  Tuesday

# %%
temp  = feature[feature['user'] != 'group_notification' ]

# %%
new_temp = temp[temp['message'] != '<Media omitted>']

# %%
f = open('hinglish.txt','r')
stop_words = f.read()
stop_word = stop_words.split('\n')

# %%
words = []
for message in new_temp['message']:
    for word in message.lower().split():
        if word not in stop_word:
            words.append(word)
    #words.extend(message.split())

# %%
words
# Out:
# ['@917023261804',
#  'roof',
#  'click',
#  'pic',
#  'share',
#  'dena',
#  'dua',
#  'bhej',
#  'photo',
#  'saale',
#  '@919461517537',
#  'message',
#  'deleted',
#  'jasmin',
#  'photo',
#  'bhej',
#  'dena',
#  'avneesh',
#  'reh',
#  'gya',
#  'special',
#  'lagata',
#  'ruk',
#  'message',
#  'deleted',
#  'beth',
#  'yaaro',
#  'train',
#  'bdiya',
#  'gand',
#  'mara',
#  'hame',
#  'bta',
#  'bhaiyo',
#  '2-3',
#  'dino',
#  'bahar',
#  'jana',
#  'band',
#  'high',
#  'probability',
#  '😂',
#  'dheeraj',
#  'fass',
#  'hass',
#  'ku',
#  'lodu',
#  'single',
#  'rahega',
#  'isliye',
#  '😂',
#  'ku',
#  'meena',
#  'dheeraj',
#  'jagah',
#  'soyega',
#  'mna',
#  'lodu',
#  'sone',
#  'reached',
#  'wapas',
#  'ander',
#  'aane',
#  'jugaad',
#  'liyo',
#  '*halwa',
#  '@917023261804',
#  '@919694454385',
#  'message',
#  'deleted',
#  'message',
#  'deleted',
#  'message',
#  'deleted',
#  'etna',
#  'ghatiya',
#  'ah',
#  'khakar',
#  'chomu',
#  'majak',
#  'dekhna',
#  'lag',
#  '@919461517537',
#  '😂😂😂😂😂',
#  'bhej',
#  'roorkee',
#  'tereko',
#  'entry',
#  'dilwayenge',
#  '🫂',
#  'aa',
#  'jaunga',
#  '🤘',
#  'keshav',
#  'kaushik',
#  'm4',
#  '👊🏻',
#  '@919694454385',
#  'room',
#  'issue',
#  'set',
#  'karan',
#  'puch',
#  'aree',
#  'free',
#  'kare😂',
#  'pahunch',
#  'kya?',
#  'bhatinda',
#  'pahuchna',
#  'train',
#  'jaldi',
#  'kha',
#  'ana',
#  'dudh',
#  'varna',
#  '100%',
#  'pure',
#  'water',
#  'mix',
#  'hoke',
#  'milega',
#  'hmmm',
#  'ha',
#  'aa',
#  'clg',
#  'saale',
#  'jaldi',
#  'aaja',
#  'week',
#  'tou',
#  'lagega',
#  'prem',
#  'aa',
#  'paunga',
#  'aa',
#  '26',
#  'gate',
#  'band',
#  'tou',
#  'jugaad',
#  'lenge',
#  'hope',
#  'gand',
#  'mara',
#  'ham',
#  'jante',
#  'hmko',
#  'meena',
#  'diwar',
#  'jugaad',
#  'special',
#  'bolega',
#  'aaunga',
#  'gm',
#  'saale',
#  '😂',
#  'hat',
#  'bheja',
#  'cllg',
#  'walo',
#  'mail',
#  'dal',
#  'dinga',
#  'message',
#  'deleted',
#  '😂😂',
#  'gulab',
#  'jamun',
#  'chamach',
#  'haath',
#  'kha',
#  'gulab',
#  'jamun',
#  'chamch',
#  'khtm👽👽',
#  'ajj',
#  'dinner',
#  'nan,',
#  'paneer,',
#  'fruit',
#  'raita,papad,',
#  'gulab',
#  'jamun,',
#  'dal',
#  'makhni,',
#  'aalu',
#  'dam',
#  'mjja',
#  'aa',
#  'gya',
#  '@919772881641',
#  ',@919461517537',
#  'week',
#  'manu',
#  'guess',
#  'library',
#  'meena',
#  'weak',
#  'decide',
#  'bed',
#  'tou',
#  'soya',
#  '😂',
#  'bhadiya',
#  'maje',
#  'purra',
#  'din',
#  'bs',
#  'aa',
#  'h?',
#  'aaega',
#  'saale',
#  '@919772881641',
#  'jaaldi',
#  'aaja',
#  'cogni',
#  'c***e',
#  'jarurat.',
#  '😂',
#  'null',
#  'yaar',
#  '30',
#  'tou',
#  'sari',
#  'trains',
#  'full',
#  '🤧',
#  'fass',
#  'yaar',
#  'enjoy',
#  'home',
#  '😂😂',
#  '😂',
#  'aa',
#  'aaja',
#  'humko',
#  'nikal',
#  '😥',
#  'haye',
#  'haye',
#  'happy',
#  'year',
#  'boys',
#  '💟💟🎉🎉',
#  '++',
#  '🔥🔥🔥',
#  '++',
#  'bhaje',
#  'aajaoye',
#  'ge',
#  'raat',
#  'bheed',
#  'rheti',
#  'raat',
#  'aa',
#  'paenge',
#  'ganga',
#  'pass',
#  'baith',
#  'jaana',
#  'pure',
#  'din',
#  'pakda',
#  'eski',
#  'chasma',
#  'laga',
#  'wapas',
#  'jaana',
#  'salee',
#  'bcc',
#  '😂',
#  'majak',
#  'saala',
#  'dikkat',
#  'aa',
#  'aana',
#  'denga',
#  'wapas',
#  'bhejega',
#  'bhej',
#  'kh',
#  'dena',
#  'tikkat',
#  '😅',
#  'hor',
#  'mayank',
#  'bhadiya',
#  'esko',
#  'aana',
#  'jake',
#  'lana',
#  'padega',
#  'abb',
#  'pakka',
#  'lena',
#  '@919461517537',
#  'chutiya',
#  'aa',
#  'lene',
#  'chalenge',
#  '@919772881641',
#  '😂',
#  'ha',
#  'bula',
#  'lena',
#  '😂',
#  'kitte',
#  'baje',
#  'aana',
#  '@919772881641',
#  'jaada',
#  'chances',
#  'pakde',
#  'jaane',
#  'raat',
#  'aaega',
#  'rhega',
#  'acc',
#  'jayda',
#  'walo',
#  'aayenge',
#  'call',
#  'padega',
#  'chahiya',
#  'bta',
#  'message',
#  'deleted',
#  '😂😂',
#  'reached',
#  'utho',
#  '9.30',
#  'nikalo',
#  '6am',
#  'khulta',
#  'century',
#  'gate',
#  '@917023261804',
#  'bhal',
#  'chance',
#  'sambhal',
#  'lena',
#  'beg',
#  'aana',
#  'ruk',
#  'khana',
#  'kha',
#  'gate',
#  'pahuch',
#  'aaja',
#  'aagaya',
#  'ander',
#  'phir',
#  'bahar',
#  'baitha',
#  '@919772881641',
#  'aa',
#  '🫂🫂',
#  'chalo',
#  'bhadiya',
#  'bar',
#  'bar',
#  'dp',
#  'change',
#  'pat',
#  '@919461517537',
#  'saala',
#  'change',
#  'lodu',
#  'baat',
#  'esa',
#  'saari',
#  'aa',
#  '🙂🙂',
#  '@917023261804',
#  '🥶😏',
#  'khane',
#  'aaj??',
#  'class',
#  'link',
#  'bhejna',
#  "today's",
#  'schedule',
#  ':',
#  '1.',
#  'basic',
#  'manufacturing',
#  'processes',
#  '(min-102)',
#  'timings',
#  '9:00',
#  '10:00',
#  'teams',
#  'link',
#  ':',
#  'https://teams.microsoft.com/l/channel/19%3avruwqdkx2jo5pnhmvv4pz0selstelk95_m4_zlrd2341%40thread.tacv2/general?groupid=57c11647-60f2-4b27-a19e-c11bf8c508cb&tenantid=38f62926-7559-4aef-84ae-cb5e172406fb',
#  '2.',
#  'waste',
#  'water',
#  'engineering',
#  '(cen-202)',
#  'timings',
#  ':',
#  '10',
#  '-11',
#  'teams',
#  'link',
#  ':',
#  '*m1-m4*-',
#  'https://teams.microsoft.com/l/team/19%3a-zbjst1jhbqpaab_nc2pxfhdm72qgfhw7vbtyhpcqdu1%40thread.tacv2/conversations?groupid=e68bf56f-5ed9-41a0-ad96-a06d66b81bc4&tenantid=38f62926-7559-4aef-84ae-cb5e172406fb',
#  '*m5-m8*',
#  'team',
#  'code-',
#  'lc131yu',
#  '3.',
#  'structutal',
#  'analysis',
#  '(',
#  'cen-206)',
#  'timings',
#  ':',
#  '11',
#  '12',
#  'source',
#  ':',
#  'teams',
#  '4.',
#  'design',
#  'rce',
#  '(cen-208)',
#  'timings',
#  ':',
#  '12',
#  'pm',
#  'team',
#  'code',
#  ':',
#  'fn4w9p5',
#  'class',
#  'link',
#  'bhej',
#  'request',
#  'accept',
#  'sir',
#  'https://teams.microsoft.com/l/channel/19%3avruwqdkx2jo5pnhmvv4pz0selstelk95_m4_zlrd2341%40thread.tacv2/general?groupid=57c11647-60f2-4b27-a19e-c11bf8c508cb&tenantid=38f62926-7559-4aef-84ae-cb5e172406fb',
#  'class',
#  'start',
#  'gyi',
#  'kya?',
#  '👍',
#  '204',
#  'chl',
#  'class👽',
#  '@919115293895',
#  '@919772881641',
#  '@919694454385',
#  '@919478728000',
#  '@919461517537',
#  '@919950965459',
#  '@916280264969',
#  '@917023261804',
#  'aa',
#  'gya',
#  'monday',
#  'cws',
#  '35😂😂',
#  'link',
#  'bhej',
#  'invited',
#  'teams',
#  'meeting!',
#  'channel',
#  'meeting',
#  'https://teams.microsoft.com/l/meetup-join/19%3acolpcqd-k7e9722cc2ya7qdw6kzmgbewwidvp4pgg0m1%40thread.tacv2/1641270423596?context=%7b%22tid%22%3a%2238f62926-7559-4aef-84ae-cb5e172406fb%22%2c%22oid%22%3a%22afb3a226-f21b-474f-afe7-8a0ed1a71a9d%22%7d',
#  'tap',
#  'link',
#  'paste',
#  'browser',
#  'join.',
#  'bakchodi',
#  'profs',
#  'acad',
#  'tt',
#  'pasand',
#  'nui',
#  'aarha',
#  'sir',
#  'hope.de',
#  'hao',
#  'virus',
#  'bo,',
#  '😂',
#  'highway',
#  'engineering',
#  'attendance',
#  'leta',
#  'hai??',
#  'data',
#  'pass',
#  'aa',
#  'sayd',
#  'chutiyo',
#  'jao',
#  'man',
#  'jaao',
#  'vela',
#  '??',
#  '😀',
#  'kya?',
#  '+++',
#  'gandu',
#  'ku',
#  'saalo',
#  'khol',
#  'aajkal',
#  'jaldi',
#  'uthana',
#  'lag',
#  'hogaya',
#  'jawahar',
#  'bois',
#  ',',
#  'f',
#  'block',
#  'confirmed',
#  'case',
#  'dhyaan',
#  'rehnaa',
#  'covid',
#  'class',
#  'ku',
#  'uthaya',
#  'सोते',
#  'हैं',
#  'class',
#  'leave',
#  'class',
#  '😂',
#  'mujhse',
#  'remove',
#  'metting',
#  ',',
#  'majak',
#  'meeting',
#  'chutiya',
#  'aa',
#  'rukk',
#  'jane',
#  'bsdk',
#  'kaushik',
#  'message',
#  'deleted',
#  'chutiya',
#  'bna',
#  'saala',
#  'safai',
#  'pass',
#  'nail',
#  'cutter',
#  'kya?',
#  'room',
#  'friend',
#  'aman',
#  'borkar',
#  'beeen',
#  'tested',
#  'positive',
#  'f-block',
#  'room',
#  'mate',
#  'bhuvnesh',
#  'dheeraj',
#  'lene',
#  'tughe',
#  'clg',
#  'leke',
#  'tb',
#  'gt/gpt',
#  'bnde',
#  'unme',
#  'bhuvnesh',
#  'uski',
#  'report',
#  'negative',
#  'aayi',
#  'aman',
#  'bataya',
#  'dheeraj',
#  'janta',
#  '(for',
#  'records)',
#  'dheeraj',
#  '+',
#  '❤️❤️',
#  '+1',
#  'janta',
#  'sbko',
#  'janta',
#  'photoshop',
#  'cec',
#  'quarantine',
#  'positive',
#  'khosla',
#  'me😎👽',
#  'https://iitroorkee.webex.com/iitroorkee/j.php?mtid=mee53f404f8f677ce04946f2af961087d',
#  'subject',
#  'tutorial',
#  'mila',
#  'hritvik',
#  'nikala',
#  'nikal',
#  'jaarha',
#  'jisko',
#  'jana',
#  'chala',
#  'kausik',
#  'okk',
#  '@919115293895',
#  'khana',
#  'khane',
#  'chaloge',
#  '@jo',
#  'campus',
#  'jao',
#  'man',
#  '@919772881641',
#  '❤️❤️',
#  'gaand',
#  'mara',
#  '15',
#  'min',
#  '😂😂😂',
#  'jao',
#  'jisko',
#  'jaanah',
#  'gaand',
#  'fatjayegi',
#  'phir',
#  'jaunga',
#  'ha',
#  'loduchand',
#  'bath',
#  'baith*',
#  'koina',
#  'almari',
#  'dena',
#  'lunch',
#  '🙋🏼\u200d♂️',
#  '+1',
#  'movie',
#  'plan',
#  '@jo',
#  'campus',
#  'konsi',
#  'purani',
#  'comedy',
#  'puspa',
#  'dekhni',
#  'https://youtu.be/_o61acnmrcu',
#  'dekhna',
#  '🔥🔥',
#  'class',
#  'start',
#  'sir',
#  'busy',
#  'show',
#  'uth',
#  'gaaya',
#  'gyi',
#  'deleted',
#  'message',
#  'deleted',
#  'message',
#  'clear',
#  'bhej🤡🤡',
#  'printer',
#  'kharab',
#  '🤦🏼\u200d♂️🤦🏼\u200d♂️',
#  '😂',
#  'whaan',
#  'kr',
#  'leta😂😂',
#  'change',
#  'mile',
#  'roj',
#  'gulabjamun',
#  'krdiya',
#  'jaae',
#  'unlimited😋😋',
#  '@919694454385',
#  '@919115293895',
#  'jane',
#  'messe',
#  'menu',
#  'pav',
#  'bhaji',
#  'burger',
#  'add',
#  'gya.',
#  'mja',
#  'aa',
#  'gya',
#  '++🤩🤩',
#  'back😎😎😌😌😏😏',
#  'structural',
#  'class',
#  'link',
#  'invited',
#  'teams',
#  'meeting!',
#  'lecture',
#  'class:',
#  'ii',
#  'https://teams.microsoft.com/l/meetup-join/19%3afgzx5_qaql1xwfq6ucolftkeii_5cnpdvkonvvwe3is1%40thread.tacv2/1641960585320?context=%7b%22tid%22%3a%2238f62926-7559-4aef-84ae-cb5e172406fb%22%2c%22oid%22%3a%222f901c76-0e6a-47e3-8ba4-d0c17a53f556%22%7d',
#  'tap',
#  'link',
#  'paste',
#  'browser',
#  'join.',
#  'mail',
#  'ha',
#  'class',
#  'link',
#  'teams',
#  'share',
#  'hai😂',
#  '......',
#  'hai🤦🏼\u200d♂️🤦🏼\u200d♂️',
#  'mail',
#  'timing',
#  'mail',
#  'link',
#  'mail',
#  'webex',
#  'meet',
#  'class',
#  'teams',
#  'na🤔',
#  'teams',
#  'join',
#  'krta',
#  'tha🤦🏼\u200d♂️🤦🏼\u200d♂️😂😂',
#  'link',
#  'bhej',
#  'webex',
#  'record',
#  'lena',
#  'yaar',
#  'webex',
#  'ko.koi',
#  'link',
#  'record',
#  'karegee',
#  'rukk',
#  'https://iitroorkee.webex.com/iitroorkee/j.php?mtid=mee53f404f8f677ce04946f2af961087d',
#  'link',
#  'bhej',
#  'saale',
#  'purana',
#  'message',
#  'deleted',
#  'message',
#  'deleted',
#  'chl',
#  'class',
#  'chapo',
#  'dede🥳🥳',
#  'karle',
#  'paise',
#  'aagaye',
#  'tou',
#  'muje',
#  'chaopo',
#  'dena',
#  'kisika',
#  'cen',
#  '208',
#  'tut',
#  'deadline',
#  'kb',
#  'start',
#  'karle',
#  'bhej',
#  'dena',
#  '😂',
#  'structure',
#  'leacture',
#  'record',
#  '@919115293895',
#  ',@916280264969',
#  'message',
#  'deleted',
#  'wastewater',
#  'structural',
#  'link',
#  'daal',
#  'deta',
#  'https://drive.google.com/drive/folders/1wx-8gvm3xkznz_rdh4wsg7dnoir2ghf-?usp=sharing',
#  'structural',
#  'https://drive.google.com/drive/folders/1k7ggtwpkboid4ewsweztzueoef7k12is?usp=sharing',
#  'waste',
#  'water',
#  '@919115293895',
#  '🫂🫂',
#  '🫂🫂🫂🫂🫂+1',
#  '++🫂🫂',
#  '@917023261804',
#  'macha',
#  'class',
#  '🔥🔥🔥',
#  'शानदार',
#  'team',
#  'website',
#  'bnani',
#  'case',
#  'study',
#  'topic',
#  'krlete',
#  'kb',
#  'program',
#  'hai🥜🥜',
#  'kb',
#  'mail',
#  'muze',
#  'hua🥲',
#  'forward',
#  'krde',
#  'idhr',
#  'https://dare2compete.com/o/8bethgm?lb=xigkucy',
#  'happy',
#  'lohri',
#  'yaaro',
#  '++',
#  'krte',
#  'yaaro',
#  'happy',
#  'lohri',
#  '💥',
#  '+1',
#  'happy',
#  'makar',
#  'sankranti',
#  '🎉🎉🎇',
#  'friends',
#  '++',
#  '+)2)',
#  '+1',
#  '*urgent',
#  'requirement*',
#  'frontend-',
#  'react',
#  'js',
#  'backend-',
#  'nodejs',
#  'mobile',
#  'app-',
#  'flutter',
#  'paid',
#  'internship/',
#  'freelance',
#  'projects',
#  'contact-7509467222',
#  'canteen',
#  'tou',
#  'coffee',
#  'la',
#  'plz',
#  'hat',
#  'saalr',
#  'paas',
#  'gel',
#  'pen',
#  '@919772881641',
#  '@919478728000',
#  '@919950965459',
#  '@917023261804',
#  'ball',
#  'pen',
#  'gel',
#  'pen',
#  'assignment',
#  'neatness',
#  '#extramarksforgoodhandwriting',
#  'kanteen',
#  'chalna',
#  'aaja',
#  'sach',
#  'yep',
#  'atta',
#  'ruk',
#  'pass',
#  'blank',
#  'register',
#  'hai🎀🎀',
#  'subah',
#  'aas',
#  'pass',
#  'jagha',
#  'dena',
#  'gate',
#  'kholke',
#  'sone',
#  '++',
#  'krega',
#  'itti',
#  'jldi',
#  'uthke',
#  'message',
#  'deleted',
#  'message',
#  'deleted',
#  'message',
#  'deleted',
#  'slow',
#  'internet',
#  'message',
#  'deleted',
#  'restart',
#  'message',
#  'deleted',
#  'laptop',
#  'restart',
#  'karliya',
#  'antivirus',
#  'delete',
#  'karde',
#  'discord',
#  'aaja',
#  'stream',
#  'class',
#  'start',
#  'badhiya',
#  'yaar',
#  '😎😎😎',
#  'class',
#  'shuru',
#  'bta',
#  'dena',
#  'class',
#  'link',
#  'bhejo',
#  'yr',
#  'record',
#  'dena',
#  'plz',
#  'https://iitroorkee.webex.com/iitroorkee/j.php?mtid=mee53f404f8f677ce04946f2af961087d',
#  '🫂🫂🫂🫂❤️',
#  '👍🏻',
#  'link',
#  'class',
#  'lodu',
#  'soja',
#  'class',
#  'start',
#  'krdu',
#  'bs',
#  'quiz',
#  'koi🥶🥶',
#  'okk😌',
#  '😂',
#  '😂',
#  'highway',
#  'assignment',
#  'nahi.bhai',
#  'recording',
#  'upload',
#  '@916280264969',
#  '@919115293895',
#  'soo',
#  '@919115293895',
#  'hope',
#  'recording',
#  'uploaded',
#  '🫂🫂',
#  'धन्यवाद',
#  'भ्राताश्री',
#  'maze',
#  '++❤️❤️',
#  'wastewater',
#  'recording',
#  'video',
#  'naam',
#  'change',
#  ',',
#  'pahela',
#  'lecture',
#  'thai',
#  'lecture',
#  '👍👍',
#  'sir',
#  'class',
#  'kyo',
#  'leave',
#  'krdi',
#  'aa',
#  'message',
#  'deleted',
#  'message',
#  'deleted',
#  'class',
#  ...]

# %%
from collections import Counter

# %%
pd.DataFrame(Counter(words).most_common(20))
# Out:
#                 0   1
# 0         message  92
# 1         deleted  90
# 2           class  48
# 3              aa  38
# 4               😂  35
# 5            dena  32
# 6              ++  30
# 7   @917023261804  27
# 8             tou  27
# 9            link  26
# 10           bhej  24
# 11             ha  20
# 12  @919772881641  19
# 13          happy  19
# 14           mail  18
# 15             +1  17
# 16              /  17
# 17             gm  16
# 18        dheeraj  15
# 19              :  15

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in c:\users\dheeraj chouhan\appdata\local\programs\python\python39\lib\site-packages (1.7.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\dheeraj chouhan\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import emoji

# %%
emojis = []
for message in feature['message']:
    emojis.extend([c for c in message if c in emoji.UNICODE_EMOJI['en']])

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
#     0   1
# 0   😂  97
# 1   🫂  56
# 2   🔥  43
# 3   ❤  21
# 4   🎉  17
# .. ..  ..
# 63  🍬   1
# 64  ☹   1
# 65  🤑   1
# 66  😔   1
# 67  🫣   1
#
# [68 rows x 2 columns]

# %%
feature
# Out:
#                     user                                          message  \
# 0     group_notification          Hritvik M3 created group "Jawahar bois"
# 1     group_notification                             Hritvik M3 added you
# 2     group_notification                              You're now an admin
# 3           Karan Dua M3                                  <Media omitted>
# 4           Karan Dua M3                                  <Media omitted>
# ...                  ...                                              ...
# 2169             Dheeraj                         Hame polibazi nahi karni
# 2170        Karan Dua M3         M bhi nhi karna chata par phone aaya tha
# 2171             Dheeraj                                       Tou tu kar
# 2172             Dheeraj  @917023261804 5k me se 3k ki hame chapo de diyo
# 2173             Dheeraj                          Jayda nahi chahiye hame
#
#       Year     Month  Day  Hours  Minute  Month_num   only_date day_name
# 0     2021  December   14      1      47         12  2021-12-14  Tuesday
# 1     2021  December   14      1      47         12  2021-12-14  Tuesday
# 2     2021  December   14      1      47         12  2021-12-14  Tuesday
# 3     2021  December   14      2      11         12  2021-12-14  Tuesday
# 4     2021  December   14      2      11         12  2021-12-14  Tuesday
# ...    ...       ...  ...    ...     ...        ...         ...      ...
# 2169  2022      June    3     11      39          6  2022-06-03   Friday
# 2170  2022      June    3     11      39          6  2022-06-03   Friday
# 2171  2022      June    3     11      39          6  2022-06-03   Friday
# 2172  2022      June    3     16      56          6  2022-06-03   Friday
# 2173  2022      June    3     16      57          6  2022-06-03   Friday
#
# [2174 rows x 10 columns]

# %%
Timeline = feature.groupby(['Year','Month_num','Month']).count()['message'].reset_index()

# %%
time = []

# %%
for i in range(Timeline.shape[0]):
    time.append(Timeline['Month'][i]+ '-' + str(Timeline['Year'][i]))

# %%
Timeline['Time'] = time

# %%
Timeline
# Out:
#    Year  Month_num     Month  message           Time
# 0  2021         12  December      295  December-2021
# 1  2022          1   January      496   January-2022
# 2  2022          2  February      478  February-2022
# 3  2022          3     March      335     March-2022
# 4  2022          4     April      169     April-2022
# 5  2022          5       May      360       May-2022
# 6  2022          6      June       41      June-2022

# %%
plt.barh(Timeline['Time'],Timeline['message'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
daily_timeline = feature.groupby('only_date').count()['message'].reset_index()

# %%
daily_timeline
# Out:
#       only_date  message
# 0    2021-12-14       29
# 1    2021-12-15       14
# 2    2021-12-16        1
# 3    2021-12-17        2
# 4    2021-12-19        2
# ..          ...      ...
# 136  2022-05-29        2
# 137  2022-05-30       16
# 138  2022-06-01        6
# 139  2022-06-02       25
# 140  2022-06-03       10
#
# [141 rows x 2 columns]

# %%
plt.figure(figsize = (10,8))
plt.plot(daily_timeline['only_date'],daily_timeline['message'])
plt.show()

# %%
feature['day_name'].value_counts()
# Out:
# Monday       636
# Thursday     347
# Friday       339
# Wednesday    256
# Saturday     223
# Tuesday      206
# Sunday       167
# Name: day_name, dtype: int64

# %%
feature
# Out:
#                     user                                          message  \
# 0     group_notification          Hritvik M3 created group "Jawahar bois"
# 1     group_notification                             Hritvik M3 added you
# 2     group_notification                              You're now an admin
# 3           Karan Dua M3                                  <Media omitted>
# 4           Karan Dua M3                                  <Media omitted>
# ...                  ...                                              ...
# 2169             Dheeraj                         Hame polibazi nahi karni
# 2170        Karan Dua M3         M bhi nhi karna chata par phone aaya tha
# 2171             Dheeraj                                       Tou tu kar
# 2172             Dheeraj  @917023261804 5k me se 3k ki hame chapo de diyo
# 2173             Dheeraj                          Jayda nahi chahiye hame
#
#       Year     Month  Day  Hours  Minute  Month_num   only_date day_name
# 0     2021  December   14      1      47         12  2021-12-14  Tuesday
# 1     2021  December   14      1      47         12  2021-12-14  Tuesday
# 2     2021  December   14      1      47         12  2021-12-14  Tuesday
# 3     2021  December   14      2      11         12  2021-12-14  Tuesday
# 4     2021  December   14      2      11         12  2021-12-14  Tuesday
# ...    ...       ...  ...    ...     ...        ...         ...      ...
# 2169  2022      June    3     11      39          6  2022-06-03   Friday
# 2170  2022      June    3     11      39          6  2022-06-03   Friday
# 2171  2022      June    3     11      39          6  2022-06-03   Friday
# 2172  2022      June    3     16      56          6  2022-06-03   Friday
# 2173  2022      June    3     16      57          6  2022-06-03   Friday
#
# [2174 rows x 10 columns]

# %%
period = []
for hour in feature[['day_name','Hours']]['Hours']:
    if hour == 23:
        period.append(str(hour) + '-' + str('00'))
    elif hour == 0:
        period.append(str(hour) + '-' + str(hour +1))
    else:
        period.append(str(hour) + '-' + str(hour +1))

# %%
feature['Period']  = period
# Out:
# C:\Users\DHEERA~1\AppData\Local\Temp/ipykernel_17344/1481854584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature['Period']  = period

# %%
feature.head()
# Out:
#                  user                                  message  Year  \
# 0  group_notification  Hritvik M3 created group "Jawahar bois"  2021
# 1  group_notification                     Hritvik M3 added you  2021
# 2  group_notification                      You're now an admin  2021
# 3        Karan Dua M3                          <Media omitted>  2021
# 4        Karan Dua M3                          <Media omitted>  2021
#
#       Month  Day  Hours  Minute  Month_num   only_date day_name Period
# 0  December   14      1      47         12  2021-12-14  Tuesday    1-2
# 1  December   14      1      47         12  2021-12-14  Tuesday    1-2
# 2  December   14      1      47         12  2021-12-14  Tuesday    1-2
# 3  December   14      2      11         12  2021-12-14  Tuesday    2-3
# 4  December   14      2      11         12  2021-12-14  Tuesday    2-3

# %%
import seaborn as sns
sns.heatmap(feature.pivot_table(index = 'day_name',columns = 'Period', values = 'message',aggfunc='count').fillna(0))
plt.ythick(rotation = 'horizontal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DHEERA~1\AppData\Local\Temp/ipykernel_17344/2787227216.py in <module>
#       1 import seaborn as sns
# ----> 2 sns.heatmap(feature.pivot_table(index = 'day_name',columns = 'Period', values = 'message',aggfunc='count')).fillna(0)
#       3 plt.ythick(rotation = 'horizontal')
#       4 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'fillna'
